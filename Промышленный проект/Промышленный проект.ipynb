# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Краткое-описание" data-toc-modified-id="Краткое-описание-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>Краткое описание</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-0.2"><span class="toc-item-num">0.2&nbsp;&nbsp;</span>Описание данных</a></span></li><li><span><a href="#Параметры-этапов" data-toc-modified-id="Параметры-этапов-0.3"><span class="toc-item-num">0.3&nbsp;&nbsp;</span>Параметры этапов</a></span></li><li><span><a href="#ВАЖНО!" data-toc-modified-id="ВАЖНО!-0.4"><span class="toc-item-num">0.4&nbsp;&nbsp;</span>ВАЖНО!</a></span></li></ul></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Импорт-библиотек" data-toc-modified-id="Импорт-библиотек-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Импорт библиотек</a></span></li><li><span><a href="#Выгрузка" data-toc-modified-id="Выгрузка-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Выгрузка</a></span></li><li><span><a href="#Общий-анализ,-sweetviz" data-toc-modified-id="Общий-анализ,-sweetviz-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Общий анализ, sweetviz</a></span></li><li><span><a href="#распределение-по-временным-рамкам" data-toc-modified-id="распределение-по-временным-рамкам-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>распределение по временным рамкам</a></span></li><li><span><a href="#Расчет-ошибки-МАЕ-в-эффективности-обогащения" data-toc-modified-id="Расчет-ошибки-МАЕ-в-эффективности-обогащения-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Расчет ошибки МАЕ в эффективности обогащения</a></span></li></ul></li><li><span><a href="#Предобработка" data-toc-modified-id="Предобработка-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка</a></span><ul class="toc-item"><li><span><a href="#Различия-тестовой-выборки" data-toc-modified-id="Различия-тестовой-выборки-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Различия тестовой выборки</a></span></li><li><span><a href="#Пропуски" data-toc-modified-id="Пропуски-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Пропуски</a></span></li><li><span><a href="#Выводы-по-предобработке" data-toc-modified-id="Выводы-по-предобработке-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Выводы по предобработке</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Посмотрите,-как-меняется-концентрация-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки.-Опишите-выводы." data-toc-modified-id="Посмотрите,-как-меняется-концентрация-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки.-Опишите-выводы.-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Посмотрите, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки. Опишите выводы.</a></span></li><li><span><a href="#Сравните-распределения-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках.-Если-распределения-сильно-отличаются-друг-от-друга,-оценка-модели-будет-неправильной" data-toc-modified-id="Сравните-распределения-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках.-Если-распределения-сильно-отличаются-друг-от-друга,-оценка-модели-будет-неправильной-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Сравните распределения размеров гранул сырья на обучающей и тестовой выборках. Если распределения сильно отличаются друг от друга, оценка модели будет неправильной</a></span></li><li><span><a href="#Исследуйте-суммарную-концентрацию-всех-веществ-на-разных-стадиях:-в-сырье,-в-черновом-и-финальном-концентратах" data-toc-modified-id="Исследуйте-суммарную-концентрацию-всех-веществ-на-разных-стадиях:-в-сырье,-в-черновом-и-финальном-концентратах-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Исследуйте суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах</a></span></li><li><span><a href="#Вывод-по-анализу" data-toc-modified-id="Вывод-по-анализу-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Вывод по анализу</a></span></li></ul></li><li><span><a href="#Модель" data-toc-modified-id="Модель-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Модель</a></span><ul class="toc-item"><li><span><a href="#Напишите-функцию-для-вычисления-итоговой-sMAPE." data-toc-modified-id="Напишите-функцию-для-вычисления-итоговой-sMAPE.-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Напишите функцию для вычисления итоговой sMAPE.</a></span></li><li><span><a href="#Обучите-разные-модели-и-оцените-их-качество-кросс-валидацией.-Выберите-лучшую-модель-и-проверьте-её-на-тестовой-выборке.-Опишите-выводы" data-toc-modified-id="Обучите-разные-модели-и-оцените-их-качество-кросс-валидацией.-Выберите-лучшую-модель-и-проверьте-её-на-тестовой-выборке.-Опишите-выводы-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Обучите разные модели и оцените их качество кросс-валидацией. Выберите лучшую модель и проверьте её на тестовой выборке. Опишите выводы</a></span><ul class="toc-item"><li><span><a href="#разделение-на-тест-и-трейн" data-toc-modified-id="разделение-на-тест-и-трейн-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>разделение на тест и трейн</a></span></li><li><span><a href="#Стандартизация-данных" data-toc-modified-id="Стандартизация-данных-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Стандартизация данных</a></span></li></ul></li><li><span><a href="#DummyRegressor" data-toc-modified-id="DummyRegressor-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>DummyRegressor</a></span></li><li><span><a href="#DecisionTreeRegressor" data-toc-modified-id="DecisionTreeRegressor-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>DecisionTreeRegressor</a></span></li><li><span><a href="#RandomForestRegressor" data-toc-modified-id="RandomForestRegressor-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>RandomForestRegressor</a></span></li><li><span><a href="#LinearRegression" data-toc-modified-id="LinearRegression-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>LinearRegression</a></span></li><li><span><a href="#Модель-на-тесте" data-toc-modified-id="Модель-на-тесте-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Модель на тесте</a></span></li><li><span><a href="#Вывод-по-моделям" data-toc-modified-id="Вывод-по-моделям-4.8"><span class="toc-item-num">4.8&nbsp;&nbsp;</span>Вывод по моделям</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Вступление

# %% [markdown]
# ### Краткое описание

# %% [markdown]
# Для компании, которая разрабатывает решения для эффективной работы промышленных предприятий нужно подготовить модель.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используем данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# В данной работе необходимо:
#
# Подготовить данные;
# Провести исследовательский анализ данных;
# Построить и обучить модель.

# %% [markdown]
# ### Описание данных

# %% [markdown]
# Описание данных
#
#
# Технологический процесс
#
#
# `Rougher feed` — исходное сырье
#
# `Rougher additions` (или reagent additions) — флотационные реагенты: Xanthate, Sulphate, Depressant
#
# `Xanthate` — ксантогенат (промотер, или активатор флотации);
#
# `Sulphate` — сульфат (на данном производстве сульфид натрия);
#
# `Depressant` — депрессант (силикат натрия).
#
# `Rougher process` (англ. «грубый процесс») — флотация
#
# `Rougher tails` — отвальные хвосты
#
# `Float bank`s — флотационная установка
#
# `Cleaner process` — очистка
#
# `Rougher Au` — черновой концентрат золота
#
# `Final Au` — финальный концентрат золота

# %% [markdown]
# ### Параметры этапов

# %% [markdown]
# air amount — объём воздуха
#
# fluid levels — уровень жидкости
#
# feed size — размер гранул сырья
#
# feed rate — скорость подачи
#
# Наименование признаков
#
#
# Наименование признаков должно быть такое: [этап].[тип_параметра].[название_параметра]
#
# Пример: rougher.input.feed_ag
#
# Возможные значения для блока [этап]:
#
#
# rougher — флотация
# primary_cleaner — первичная очистка
# secondary_cleaner — вторичная очистка
# final — финальные характеристики
# Возможные значения для блока [тип_параметра]:
#
#
#
# input — параметры сырья
# output — параметры продукта
# state — параметры, характеризующие текущее состояние этапа
# calculation — расчётные характеристики

# %% [markdown]
# ### ВАЖНО!

# %% [markdown]
# Для EDA установлен sweetviz и чтобы не ждать долго - я закомментил строки с их выводом
#
# При необходимости - раскомментить строки с выводом в графе "Общий анализ, sweetviz"

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Импорт библиотек

# %% [raw]
# !pip3 install pandas-profiling==2.11
# !pip3 install sweetviz
# !pip3 install flashtext

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np

# import sweetviz as sv
import seaborn as sns
from sklearn.model_selection import  cross_val_score, GridSearchCV
from sklearn.metrics import make_scorer
from sklearn.preprocessing import StandardScaler , MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.dummy import DummyRegressor

import warnings
warnings.filterwarnings('ignore')
from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)

from scipy.interpolate import interp1d
import matplotlib.pyplot as plt
import plotly
import plotly.graph_objs as go

# %% [markdown]
# ### Выгрузка

# %%
try:
    gold_recovery_train = pd.read_csv('/datasets/gold_recovery_train_new.csv',index_col='date',parse_dates=True)
except FileNotFoundError:
    gold_recovery_train = pd.read_csv('https://code.s3.yandex.net/datasets/gold_recovery_train_new.csv',index_col='date',parse_dates=True)
gold_recovery_train.head(1)
# Out:
#             final.output.concentrate_ag  final.output.concentrate_pb  \
# date
# 2016-01-15                     6.055403                     9.889648
#
#             final.output.concentrate_sol  final.output.concentrate_au  \
# date
# 2016-01-15                      5.507324                     42.19202
#
#             final.output.recovery  final.output.tail_ag  final.output.tail_pb  \
# date
# 2016-01-15              70.541216             10.411962              0.895447
#
#             final.output.tail_sol  final.output.tail_au  \
# date
# 2016-01-15              16.904297              2.143149
#
#             primary_cleaner.input.sulfate  primary_cleaner.input.depressant  \
# date
# 2016-01-15                     127.092003                         10.128295
#
#             primary_cleaner.input.feed_size  primary_cleaner.input.xanthate  \
# date
# 2016-01-15                             7.25                        0.988759
#
# ...

# %%
try:
    gold_recovery_test= pd.read_csv('/datasets/gold_recovery_test_new.csv',index_col='date',parse_dates=True)
except FileNotFoundError:
    gold_recovery_test = pd.read_csv('https://code.s3.yandex.net/datasets/gold_recovery_test_new.csv',index_col='date',parse_dates=True)
gold_recovery_test.head(1)
# Out:
#                      primary_cleaner.input.sulfate  \
# date
# 2016-09-01 00:59:59                     210.800909
#
#                      primary_cleaner.input.depressant  \
# date
# 2016-09-01 00:59:59                         14.993118
#
#                      primary_cleaner.input.feed_size  \
# date
# 2016-09-01 00:59:59                             8.08
#
#                      primary_cleaner.input.xanthate  \
# date
# 2016-09-01 00:59:59                        1.005021
#
#                      primary_cleaner.state.floatbank8_a_air  \
# date
# 2016-09-01 00:59:59                             1398.981301
#
#                      primary_cleaner.state.floatbank8_a_level  \
# date
# 2016-09-01 00:59:59                               -500.225577
#
#                      primary_cleaner.state.floatbank8_b_air  \
# date
# 2016-09-01 00:59:59                             1399.144926
#
#                      primary_cleaner.state.floatbank8_b_level  \
# date
# ...

# %%
try:
    gold_recovery_full = pd.read_csv('/datasets/gold_recovery_full_new.csv',index_col='date',parse_dates=True)
except FileNotFoundError:
    gold_recovery_full = pd.read_csv('https://code.s3.yandex.net/datasets/gold_recovery_full_new.csv',index_col='date',parse_dates=True)
gold_recovery_full.head(5)
# Out:
#                      final.output.concentrate_ag  final.output.concentrate_pb  \
# date
# 2016-01-15 00:00:00                     6.055403                     9.889648
# 2016-01-15 01:00:00                     6.029369                     9.968944
# 2016-01-15 02:00:00                     6.055926                    10.213995
# 2016-01-15 03:00:00                     6.047977                     9.977019
# 2016-01-15 04:00:00                     6.148599                    10.142511
#
#                      final.output.concentrate_sol  \
# date
# 2016-01-15 00:00:00                      5.507324
# 2016-01-15 01:00:00                      5.257781
# 2016-01-15 02:00:00                      5.383759
# 2016-01-15 03:00:00                      4.858634
# 2016-01-15 04:00:00                      4.939416
#
#                      final.output.concentrate_au  final.output.recovery  \
# date
# 2016-01-15 00:00:00                    42.192020              70.541216
# ...

# %% [markdown]
# ### Общий анализ, sweetviz

# %%
# report = sv.analyze(gold_recovery_train)
# report.show_notebook()

# %%
# report = sv.analyze(gold_recovery_test)
# report.show_notebook()

# %%
# report = sv.analyze(gold_recovery_full)
# report.show_notebook()

# %% [markdown]
# Данные представляют из себя числовые параметры датчиков на производстве, одна колонка представляет собой время замеров, все остаельное - показания, цифры.

# %% [markdown]
# ### распределение по временным рамкам

# %% [markdown]
# ---первая колонка - время. Пробежимся бегло по ней

# %%
ax_gold_recovery_test = gold_recovery_test.index.hour.value_counts().sort_index().plot(kind = 'bar',title = 'Распределение данных по часам')
ax_gold_recovery_train = gold_recovery_train.index.hour.value_counts().sort_index().plot(kind = 'bar',colormap = 'flag',alpha=0.2,figsize = (20,15))
plt.legend(['Test','Train'])
plt.xlabel('часы в сутках')
plt.ylabel('количество данных')
plt.show()

# %%
ax_gold_recovery_test = gold_recovery_test.index.weekday.value_counts().sort_index().plot(kind = 'bar',title = 'Распределение данных по часам')
ax_gold_recovery_train = gold_recovery_train.index.weekday.value_counts().sort_index().plot(kind = 'bar',colormap = 'flag',alpha=0.5,figsize = (10,7))
plt.legend(['Test','Train'])
plt.xlabel('часы в сутках')
plt.ylabel('количество данных')
plt.show()

# %%
ax_gold_recovery_test = gold_recovery_test.index.year.value_counts().sort_index().plot(kind = 'bar',title = 'Распределение данных по часам')
ax_gold_recovery_train = gold_recovery_train.index.year.value_counts().sort_index().plot(kind = 'bar',colormap = 'flag',alpha=0.2,figsize = (10,7))
plt.legend(['Test','Train'])
plt.xlabel('часы в сутках')
plt.ylabel('количество данных')
plt.show()

# %%
def time_plot(data):
    gold_recovery_train['2016-01-01':'2018-12-31'][data].plot(title = data)

    plt.xlabel('период')
    plt.ylabel('показатели датчиков')
    plt.show()
    
for i in gold_recovery_train.columns:
    time_plot(i)

# %% [markdown]
# Данные распределены нормально, нет каких либо аномалий.НО. с сентября по январь нет данных, возможно что -----
#
#
# Сезонность для золота – это нечто парадоксальное. Для товара вроде зерна, которое можно вырастить и собрать только в определенное время года, сезонность совершенно логична. Предложение зерна сильно колеблется в соответствии с небесной механикой. Но золото? В отличие от выращиваемых товаров, этот металл добывают во всем мире с отличительной стабильностью круглогодично, независимо от солнечного света, температуры или погодных условий.
#
# Но, конечно, предложение – это лишь половина ценового уравнения, столь же, если не более важным, является спрос. А по ряду интересных циклов доходности и культурных причин, спрос на золото значительно растет в определенное время календарного года. Так как предложение, формируемое за счет добычи, в основном, фиксировано и не может увеличиваться, чтобы удовлетворять эти скачки спроса, цена на золото быстро растет вверх. Сезонность золота связана со спросом.
#
#
# Ну или нам специально не предоставили этих данных

# %% [markdown]
# ### Расчет ошибки МАЕ в эффективности обогащения

# %% [markdown]
# --- по представленной формуле посчитаем МАЕ

# %%
C = gold_recovery_train["rougher.output.concentrate_au"]
F = gold_recovery_train["rougher.input.feed_au"]
T = gold_recovery_train["rougher.output.tail_au"]

# %%
gold_recovery_train["rougher.output.recovery.calculated"] = (C * (F - T)) / (F * (C - T)) * 100

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ✔️\
# <font color='green'>Расчёт верный!</font>

# %%
mae = (gold_recovery_train["rougher.output.recovery.calculated"] - gold_recovery_train["rougher.output.recovery"]).abs().sum() / len(gold_recovery_train)
print("MAE", ":", mae)
# Out:
# MAE : 9.73512347450521e-15

# %% [markdown]
# MAE имеет очень малое отклонение - это значит,считаем что Recovery посчитан верно

# %% [markdown]
# ## Предобработка

# %% [markdown]
# ### Различия тестовой выборки

# %%
delete_test = gold_recovery_train.copy()
delete_test = delete_test.drop(columns=list(gold_recovery_test.columns))
delete_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 14149 entries, 2016-01-15 00:00:00 to 2018-08-18 10:59:59
# Data columns (total 35 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   final.output.concentrate_ag                         14148 non-null  float64
#  1   final.output.concentrate_pb                         14148 non-null  float64
#  2   final.output.concentrate_sol                        13938 non-null  float64
#  3   final.output.concentrate_au                         14149 non-null  float64
#  4   final.output.recovery                               14149 non-null  float64
#  5   final.output.tail_ag                                14149 non-null  float64
#  6   final.output.tail_pb                                14049 non-null  float64
#  7   final.output.tail_sol                               14144 non-null  float64
# ...

# %% [markdown]
# ---по советам преподавателя обратил внимание на тестовую выборку и в ней отсутствуют целевые признаки 'rougher.output.recovery', 'final.output.recovery' а также значения output по всем операциям по всем элементам. Но для реального прогноза они и должны отсутсововать.
#
# ---но в тоже время в тесте не хватает целевых признаков и их добавим из данных full
#
# ---лишние колонки будут удалены перед обучением моделей

# %%
gold_recovery_test = gold_recovery_test.merge(gold_recovery_full[['final.output.recovery', 'rougher.output.recovery']], how='left', on='date')
gold_recovery_test.head(3)
# Out:
#                      primary_cleaner.input.sulfate  \
# date
# 2016-09-01 00:59:59                     210.800909
# 2016-09-01 01:59:59                     215.392455
# 2016-09-01 02:59:59                     215.259946
#
#                      primary_cleaner.input.depressant  \
# date
# 2016-09-01 00:59:59                         14.993118
# 2016-09-01 01:59:59                         14.987471
# 2016-09-01 02:59:59                         12.884934
#
#                      primary_cleaner.input.feed_size  \
# date
# 2016-09-01 00:59:59                         8.080000
# 2016-09-01 01:59:59                         8.080000
# 2016-09-01 02:59:59                         7.786667
#
#                      primary_cleaner.input.xanthate  \
# date
# 2016-09-01 00:59:59                        1.005021
# 2016-09-01 01:59:59                        0.990469
# 2016-09-01 02:59:59                        0.996043
#
#                      primary_cleaner.state.floatbank8_a_air  \
# date
# ...

# %% [markdown]
# ### Пропуски

# %% [markdown]
# ---обработаем пропуски

# %%
for df in [gold_recovery_train, gold_recovery_test, gold_recovery_full]:
    print("Дубликаты:", df.duplicated().sum())
    print("Пропуски:", df.isna().sum().sum())
    print("")
# Out:
# Дубликаты: 0
# Пропуски: 4100
#
# Дубликаты: 0
# Пропуски: 90
#
# Дубликаты: 0
# Пропуски: 4481

# %%
gold_recovery_train = gold_recovery_train.interpolate()
gold_recovery_test = gold_recovery_test.interpolate()

# %%
for df in [gold_recovery_train, gold_recovery_test, gold_recovery_full]:
    print("Дубликаты:", df.duplicated().sum())
    print("Пропуски:", df.isna().sum().sum())
    print("")
# Out:
# Дубликаты: 0
# Пропуски: 0
#
# Дубликаты: 0
# Пропуски: 0
#
# Дубликаты: 0
# Пропуски: 4481

# %% [markdown]
# ### Выводы по предобработке

# %% [markdown]
# --в изходной, тестовой и тренировочной выборках выявлены пропуски, заполнил их методом interpolate, который связывает ближайшие показания. Исходную трогать не стал, т.к. она дана , как я считаю, для восполнения удаленных данных
#
# ---к тестовой выборке дополнены таргеты
#
# ---лишние колонки будут удалены перед обучением моделей

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# --- на этом этапе постараемся посмотреть, что происходит с концентрациями металлов и с сырьем на всех этапах производства

# %% [markdown]
# ### Посмотрите, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки. Опишите выводы.

# %%
#функция построения графиков
def plot_distplot(df, col1,col2,col3,col4, title): 
    fig = plt.figure(figsize=(15,7))
    sns.distplot(df[col1])
    sns.distplot(df[col2])
    sns.distplot(df[col3])
    sns.distplot(df[col4])
    fig.legend([col1,col2,col3,col4])
    plt.xlabel(title)
    plt.ylabel('значения параметра')
    plt.show()

# %% [markdown]
# ---график концентрации золота

# %%
plot_distplot(gold_recovery_full,'rougher.input.feed_au', 'rougher.output.concentrate_au','primary_cleaner.output.concentrate_au' ,'final.output.concentrate_au', 'lkh')

# %% [markdown]
# ---график концентрации серебра

# %%
plot_distplot(gold_recovery_full,'rougher.input.feed_ag', 'rougher.output.concentrate_ag','primary_cleaner.output.concentrate_ag' ,'final.output.concentrate_ag', 'lkh')

# %% [markdown]
# ---график концентрации свинца

# %%
plot_distplot(gold_recovery_full,'rougher.input.feed_pb', 'rougher.output.concentrate_pb','primary_cleaner.output.concentrate_pb' ,'final.output.concentrate_pb', 'lkh')

# %% [markdown]
# Вывод:
#
# Концентрация золота увеличивается после каждого этапа очистки. т.к. часть пустой породы уходит в хвосты.
#
# Концентрация серебра увеличивается после флотации и уменьшается после следующих этапов
#
# Концентрация свинца снижается после первого этапа очистки и незначительно изменяется в дальнейшем

# %% [markdown]
# ### Сравните распределения размеров гранул сырья на обучающей и тестовой выборках. Если распределения сильно отличаются друг от друга, оценка модели будет неправильной

# %% [markdown]
# ---на этом этапе посмотрим размер гранул сырья, от этого показателя может зависеть итоговый выход продукта

# %%
gold_recovery_train['rougher.input.feed_size'].hist(bins=1000,figsize=(20,10))
gold_recovery_test['rougher.input.feed_size'].hist(bins=1000)

plt.legend(['Train','Test'])
plt.xlabel('Распределение размеров гранул сырья на этапе флотации')
plt.ylabel('значения параметра')
plt.show()

# %% [markdown]
# ---оба графика похожи по силуэту и у обоих есть выбросы после значения 200

# %%
gold_recovery_train[gold_recovery_train['rougher.input.feed_size']>200]['rougher.input.feed_size'].hist(bins=100,figsize=(20,10))
gold_recovery_test[gold_recovery_test['rougher.input.feed_size']>200]['rougher.input.feed_size'].hist(bins=50)

plt.legend(['Train','Test'])
plt.xlabel('Распределение размеров гранул сырья на этапе флотации')
plt.ylabel('значения параметра')
plt.show()

# %%
gold_recovery_train = gold_recovery_train[
    gold_recovery_train['rougher.input.feed_size'] <
    gold_recovery_train['rougher.input.feed_size'].quantile(q=.995)
].reset_index(drop=True)

# %% [markdown]
# ---считаю возможным удалить эти значения из трейна, как выбросы, но тестовую не трогаю, т.к. в ее мы не можем корректировать

# %% [markdown]
# ---размеры гранул сырья не выходе

# %%
gold_recovery_train['rougher.input.feed_size'].hist(bins=300,figsize=(20,10),label='train', density=True)
gold_recovery_test['rougher.input.feed_size'].hist(bins=300, alpha=0.7, label='test', density=True)

plt.legend(['Train','Test'])
plt.ylabel('значения параметра')
plt.show()

# %% [markdown]
# ---в целом  графики распределения размера гранул похожи

# %% [markdown]
# ### Исследуйте суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах

# %%
ag = gold_recovery_train['rougher.input.feed_ag']
pb = gold_recovery_train['rougher.input.feed_pb']
au = gold_recovery_train['rougher.input.feed_au']
sol = gold_recovery_train['rougher.input.feed_sol']
sum = ag+pb+au+sol
gold_recovery_train['rougher.input.feed_total'] = sum

# %%
ag = gold_recovery_train['rougher.output.concentrate_ag']
pb = gold_recovery_train['rougher.output.concentrate_pb']
au = gold_recovery_train['rougher.output.concentrate_au']
sol = gold_recovery_train['rougher.output.concentrate_sol']
sum = ag+pb+au+sol
gold_recovery_train['rougher.output.concentrate_total'] = sum

# %%
ag = gold_recovery_train['final.output.concentrate_ag']
pb = gold_recovery_train['final.output.concentrate_pb']
au = gold_recovery_train['final.output.concentrate_au']
sol = gold_recovery_train['final.output.concentrate_sol']
sum = ag+pb+au+sol
gold_recovery_train['final.output.concentrate_total'] = sum

# %%
gold_recovery_train['rougher.input.feed_total'].hist(bins=200, figsize=(20,10))
gold_recovery_train['rougher.output.concentrate_total'].hist(bins=200)
gold_recovery_train['final.output.concentrate_total'].hist(bins=200)
plt.title('your title')
plt.xlabel('флотация')
plt.ylabel('сумм. концентрация всех веществ')
plt.legend(['грубый концентрат', 'хвосты', 'очистка выход'])
plt.show()

# %% [markdown]
# ---на графике видны выбросы в нулевых значения, удалю их

# %%
gold_recovery_train = gold_recovery_train[gold_recovery_train['rougher.input.feed_total'] > 0]
gold_recovery_train = gold_recovery_train[gold_recovery_train['rougher.output.concentrate_total'] > 0]
gold_recovery_train = gold_recovery_train[gold_recovery_train['final.output.concentrate_total'] > 1]

# %%
gold_recovery_train['rougher.input.feed_au'].hist(bins=200, figsize=(20,10))
gold_recovery_train['rougher.output.concentrate_au'].hist(bins=200)
gold_recovery_train['final.output.concentrate_au'].hist(bins=200)
plt.title('your title')
plt.xlabel('флотация')
plt.ylabel('сумм. концентрация всех веществ')
plt.legend(['грубый концентрат', 'хвосты', 'очистка выход'])
plt.show()

# %% [markdown]
# ---также видно, что золото остается в хвостах

# %% [markdown]
# ### Вывод по анализу

# %% [markdown]
# ---в графике размеров исходного сырья были замечены выбросы и ликвидированы из тренировочной выборки
#
# ---в общей концентрации металлов были замечены и ликвидированы нулевые и околонулевые значения

# %% [markdown]
# ## Модель

# %% [markdown]
# ### Напишите функцию для вычисления итоговой sMAPE.

# %% [markdown]
# ---функция написана не без помощи преподавателя, и показвывет среднее абсолютное процентное значение. Она одинаково расчитывает данные целевого признака и предсказательной модели

# %%
def smape(y_true, y_pred):
    smape = ((np.abs(y_true - y_pred)/((np.abs(y_true) + np.abs(y_pred))/2))).mean()
    return smape

# %%
def smape_final(y_true, y_pred):
    smape_out_rougher = smape(y_true[:,0], y_pred[:,0])
    smape_out_final =smape(y_true[:,1], y_pred[:,1])
    return (0.25 * smape_out_rougher) + (0.75 * smape_out_final)

smape_score = make_scorer(smape)

smape_score_final = make_scorer(smape_final)

# %% [markdown]
# ### Обучите разные модели и оцените их качество кросс-валидацией. Выберите лучшую модель и проверьте её на тестовой выборке. Опишите выводы

# %% [markdown]
# #### разделение на тест и трейн

# %% [markdown]
# ---сначала удалю из тренировочных данных лишние колонки

# %%
delete = set(gold_recovery_train.columns) - set(gold_recovery_test.columns)
gold_recovery_train= gold_recovery_train.drop(columns = delete) 
print(gold_recovery_train.shape)
print(gold_recovery_test.shape)
# Out:
# (13724, 54)
# (5290, 54)

# %% [markdown]
# ---причем для теста выделим два целевых признака

# %%
features_train = gold_recovery_train.drop(['rougher.output.recovery', 'final.output.recovery'], axis=1)
features_test = gold_recovery_test.drop(['rougher.output.recovery', 'final.output.recovery'], axis=1)
target_train = gold_recovery_train[['rougher.output.recovery', 'final.output.recovery']]
target_test = gold_recovery_test[['rougher.output.recovery', 'final.output.recovery']]
target_test_final = gold_recovery_test['final.output.recovery']
target_test_rougher = gold_recovery_test['rougher.output.recovery']
target_train_final = gold_recovery_train[['final.output.recovery']]
target_train_rougher = gold_recovery_train[['rougher.output.recovery']]

# %% [markdown]
# #### Стандартизация данных

# %%
scaler = MinMaxScaler()
scaler.fit(features_train)

features_train = scaler.transform(features_train)
features_test  = scaler.transform(features_test)

target_train = target_train.values
target_test = target_test.values


target_test_final = target_test_final.values
target_train_final = target_train_final.values


target_train_rougher = target_train_rougher.values
target_test_rougher = target_test_rougher.values

# %% [markdown]
# ### DummyRegressor

# %%
dummy_regr = DummyRegressor(strategy="mean")
dummy_regr.fit(features_train, target_train)
dummy_regr_test_predictions = dummy_regr.predict(features_test)

print('Базовая модель sMAPE :', '{:.2%}'.format(smape_final(target_test, dummy_regr_test_predictions)))
# Out:
# Базовая модель sMAPE : 9.80%

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ✔️\
# <font color='green'> Классно, что сравниваешь с константной моделью!</font>

# %% [markdown]
# ### DecisionTreeRegressor

# %%
for i in range(1, 16, 2):
    dt = DecisionTreeRegressor(max_depth = i, random_state = 12345)
    dt.fit(features_train, target_train)
    cross_val_scores_dt = cross_val_score(dt, features_train, target_train, cv=5, scoring=smape_score_final)
    print('Max depth: ' + str(i) + ', sMAPE: {:.2%}'.format(abs(cross_val_scores_dt.mean())))
# Out:
# Max depth: 1, sMAPE: 8.94%
# Max depth: 3, sMAPE: 9.08%
# Max depth: 5, sMAPE: 10.46%
# Max depth: 7, sMAPE: 10.99%
# Max depth: 9, sMAPE: 13.37%
# Max depth: 11, sMAPE: 14.21%
# Max depth: 13, sMAPE: 14.31%
# Max depth: 15, sMAPE: 15.27%

# %% [markdown]
# ### RandomForestRegressor

# %%
for n in range(1, 32, 10):
    for i in range(1, 10, 2):
        rf = RandomForestRegressor(n_estimators = n, max_depth = i,  random_state = 12345)
        rf.fit(features_train, target_train)
        cross_val_scores_rf = cross_val_score(rf, features_train, target_train, cv=5, scoring=smape_score_final)
        print('n_estimators: ' + str(n) + '  max_depth: ' + str(i) + ', sMAPE: {:.2%}'.format(abs(cross_val_scores_rf.mean())))
# Out:
# n_estimators: 1  max_depth: 1, sMAPE: 9.55%
# n_estimators: 1  max_depth: 3, sMAPE: 9.63%
# n_estimators: 1  max_depth: 5, sMAPE: 9.38%
# n_estimators: 1  max_depth: 7, sMAPE: 11.68%
# n_estimators: 1  max_depth: 9, sMAPE: 13.07%
# n_estimators: 11  max_depth: 1, sMAPE: 8.96%
# n_estimators: 11  max_depth: 3, sMAPE: 8.56%
# n_estimators: 11  max_depth: 5, sMAPE: 8.89%
# n_estimators: 11  max_depth: 7, sMAPE: 9.22%
# n_estimators: 11  max_depth: 9, sMAPE: 9.18%
# n_estimators: 21  max_depth: 1, sMAPE: 8.94%
# n_estimators: 21  max_depth: 3, sMAPE: 8.55%
# n_estimators: 21  max_depth: 5, sMAPE: 9.00%
# n_estimators: 21  max_depth: 7, sMAPE: 9.12%
# n_estimators: 21  max_depth: 9, sMAPE: 9.29%
# n_estimators: 31  max_depth: 1, sMAPE: 8.93%
# n_estimators: 31  max_depth: 3, sMAPE: 8.58%
# n_estimators: 31  max_depth: 5, sMAPE: 9.05%
# n_estimators: 31  max_depth: 7, sMAPE: 9.07%
# n_estimators: 31  max_depth: 9, sMAPE: 9.31%

# %% [markdown]
# ### LinearRegression

# %%
lr_regr = LinearRegression().fit(features_train, target_train) # train the model 
lr_regr_test_predictions = lr_regr.predict(features_test)
cv_score_lr = cross_val_score(lr_regr, features_train, target_train, cv=5, scoring=smape_score_final)
print('sMAPE:  {:.2%}'.format(abs(cv_score_lr.mean())))
# Out:
# sMAPE:  10.01%

# %% [markdown]
# ### Модель на тесте

# %% [markdown]
# ---лучшая модель оказалась RandomForest. на параметрах est = 20 и глубине 3

# %%
rf = RandomForestRegressor(n_estimators = 20, max_depth = 3,  random_state = 12345)
rf.fit(features_train, target_train_final)

predicted_test_final = rf.predict(features_test)

scores_final = smape(target_test_final,predicted_test_final)

print( 'sMAPE: {:.2%}'.format(abs(scores_final.mean())))
# Out:
# sMAPE: 9.47%

# %%
rf = RandomForestRegressor(n_estimators = 20, max_depth = 3,  random_state = 12345)
rf.fit(features_train, target_train_rougher)

predicted_test_rougher = rf.predict(features_test)

scores_rougher = smape(target_test_rougher,predicted_test_rougher)

print( 'sMAPE: {:.2%}'.format(abs(scores_rougher.mean())))
# Out:
# sMAPE: 8.53%

# %%
print('ИТОГОВЫЙ sMAPE------------- {:.2%}'.format(0.25 * scores_final.mean() + 0.75 * scores_rougher.mean()))
# Out:
# ИТОГОВЫЙ sMAPE------------- 8.77%

# %% [markdown]
# ### Вывод по моделям

# %% [markdown]
# В обучении моделей участвовали модели случайного леса, решающего дерева, линейной регрессии и константная модель. Для расширения кругозора коллеги применяют и другие модели, но без теории считаю некорректным к ним приступать.
#
# dummy модель показала 9.8%
# решающее дерево при глубине 1 - 8.94%
# случайный лес при глубине 3 и количестве деревьев 20 - 8.55%
# линейная регрессия - 10 %
#
# для теста была выбрана модель случайного леса и на таргетах показала 9.40 и 8.6, что в итоговой smape показало 8.81%

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# В поставленную задачу входили задания по подготовке данных, из анализу и применению в моделях.
#
# Вначале были выгружены данные, обследованы и сделаны выводы.
#
# На предообработке добавлены недостающие признаки, удалены лишние, нули, выбросы, написана функция ошибки МАЕ.
#
# Проведен анализ с построением графиков по концентрации металлов, распределении размеров гранул и суммарной концентрации, сделаны выводы.
#
# На этапе примения моделей написана функция sMAPE, масштабированы признаки, разделены тестовые выборки. Из изученных в теории моделей выбрана лучшая и на ней отработаны разные целевые признаки.
#
# Лучшей моделью получилась RandomForest с параметрами - кол-во деревьев - 20 , глубиной 3. Итоговая sMAPE вышла 8.81 %, в то время, как константная модель - 9.8 %
